# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
print(__doc__)

# Author: Vincent Dubourg <vincent.dubourg@gmail.com>
#         Jake Vanderplas <vanderplas@astro.washington.edu>
#         Jan Hendrik Metzen <jhm@informatik.uni-bremen.de>s
# License: BSD 3 clause

import numpy as np
from matplotlib import pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

np.random.seed(1)


def f(x):
    """The function to predict."""
    return x * np.sin(x)

# ----------------------------------------------------------------------
#  First the noiseless case
X = np.atleast_2d(np.linspace(0, 10, 40)).T

# Observations
y = f(X).ravel()

# Mesh the input space for evaluations of the real function, the prediction and
# its MSE
x = np.atleast_2d(np.linspace(0, 10, 10000)).T

# Instantiate a Gaussian Process model
kernel = C(1.0, (1e-3, 1e3)) * RBF(10, (1e-2, 1e2))
gp = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=100)

# Fit to data using Maximum Likelihood Estimation of the parameters
gp.fit(X, y)

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp.predict(x, return_std=True)

# Plot the function, the prediction and the 95% confidence interval based on
# the MSE
plt.figure()
plt.plot(x, f(x), 'r:', label=r'$f(x) = x\,\sin(x)$')
plt.plot(X, y, 'r.', markersize=10, label='Observations')
plt.plot(x, y_pred, 'b-', label='Prediction')
plt.fill(np.concatenate([x, x[::-1]]),
         np.concatenate([y_pred - 1.9600 * sigma,
                        (y_pred + 1.9600 * sigma)[::-1]]),
         alpha=.5, fc='b', ec='None', label='95% confidence interval')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.ylim(-10, 20)
plt.legend(loc='upper left')
# Out:
# Automatically created module for IPython interactive environment
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.38794231,  0.01069561]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 62, 'nit': 18, 'warnflag': 2}
#   ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.38615417, -0.0038804 ]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 67, 'nit': 20, 'warnflag': 2}
#   ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.5073967 ,  1.68793351]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 63, 'nit': 13, 'warnflag': 2}
#   ConvergenceWarning)
# ...

# %%
# Fit to data using Maximum Likelihood Estimation of the parameters
gp2 = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=9)
gp2.fit(X[::2], y[::2])

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp2.predict(x, return_std=True)

# Plot the function, the prediction and the 95% confidence interval based on
# the MSE
plt.figure()
plt.plot(x, f(x), 'r:', label=r'$f(x) = x\,\sin(x)$')
plt.plot(x, y_pred, 'b-', label='Prediction')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.ylim(-10, 20)
plt.legend(loc='upper left')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-0.02189859, -0.84321295]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 57, 'nit': 8, 'warnflag': 2}
#   ConvergenceWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:346: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "

# %%
# Fit to data using Maximum Likelihood Estimation of the parameters
gp3 = GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=10)
gp3.fit(X[::4], y[::4])

# Make the prediction on the meshed x-axis (ask for MSE as well)
y_pred, sigma = gp3.predict(x, return_std=True)

# Plot the function, the prediction and the 95% confidence interval based on
# the MSE
plt.figure()
plt.plot(x, f(x), 'r:', label=r'$f(x) = x\,\sin(x)$')
plt.plot(x, y_pred, 'b-', label='Prediction')
plt.xlabel('$x$')
plt.ylabel('$f(x)$')
plt.ylim(-10, 20)
plt.legend(loc='upper left')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\gaussian_process\gpr.py:346: UserWarning: Predicted variances smaller than 0. Setting those variances to 0.
#   warnings.warn("Predicted variances smaller than 0. "

# %%
import time

def timed_monte_carlo(func, samples):
    tic = time.perf_counter()
    
    y = func(samples)
    
    toc = time.perf_counter() - tic
    return y, toc

# %%
def f_slow(x):
    """The function to predict."""
    time.sleep(3)
    return x * np.sin(x)

f2 = lambda samp: gp2.predict(samp, return_std = False)
f3 = lambda samp: gp3.predict(samp, return_std = False)
timed_monte_carlo(f_slow, x)
# Out:
# (0.7843188660266874, 3.0037964000000557)

# %%
timed_monte_carlo(f2, x)
# Out:
# (0.7843213632179424, 0.0040496000001439825)

# %%
timed_monte_carlo(f3, x)
# Out:
# (0.7749680866651761, 0.0012742000001253473)
