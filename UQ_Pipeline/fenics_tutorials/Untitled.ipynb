# %% [markdown]
# # Fenics trial
#
# Solve a 1-D diffusion problem with constant diffusivity and fixed value boundary conditions such that
#
# $\frac{\partial \phi}{\partial t} = D \nabla^2 \phi$

# %%
from fipy import CellVariable, FaceVariable, Grid2D, DiffusionTerm, Viewer
from fipy.tools import numerix

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\gaussCellGradVariable.py:74: RuntimeWarning: overflow encountered in true_divide
#   return grad / volumes
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\arithmeticCellToFaceVariable.py:32: RuntimeWarning: invalid value encountered in subtract
#   return (cell2 - cell1) * alpha + cell1
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\arithmeticCellToFaceVariable.py:32: RuntimeWarning: invalid value encountered in add
#   return (cell2 - cell1) * alpha + cell1
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\variable.py:1122: RuntimeWarning: invalid value encountered in multiply
#   return self._BinaryOperatorVariable(lambda a, b: a*b, other)
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\faceGradVariable.py:124: RuntimeWarning: invalid value encountered in subtract
#   N = (N2 - numerix.take(self.var, id1, axis=-1)) / dAP
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\faceGradVariable.py:124: RuntimeWarning: overflow encountered in true_divide
#   N = (N2 - numerix.take(self.var, id1, axis=-1)) / dAP
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\faceGradContributionsVariable.py:46: RuntimeWarning: invalid value encountered in multiply
#   return self.mesh._areaProjections[(slice(0, None, None),) + (numerix.newaxis,) * (len(faceValue.shape) - 1) + (slice(0, None, None),)] * faceValue[numerix.newaxis]
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\faceGradVariable.py:136: RuntimeWarning: invalid value encountered in multiply
#   t1grad1 = numerix.sum(tangents1[s] * grad1, 0)
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\faceGradVariable.py:137: RuntimeWarning: invalid value encountered in multiply
#   t1grad2 = numerix.sum(tangents1[s] * grad2, 0)
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\faceGradVariable.py:138: RuntimeWarning: invalid value encountered in multiply
#   t2grad1 = numerix.sum(tangents2[s] * grad1, 0)
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\faceGradVariable.py:139: RuntimeWarning: invalid value encountered in multiply
#   t2grad2 = numerix.sum(tangents2[s] * grad2, 0)
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\faceGradVariable.py:141: RuntimeWarning: overflow encountered in add
#   T1 = (t1grad1 + t1grad2) / 2.
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\variables\faceGradVariable.py:144: RuntimeWarning: invalid value encountered in multiply
#   return normals[s] * N[numerix.newaxis] + tangents1[s] * T1[numerix.newaxis] + tangents2[s] * T2[numerix.newaxis]
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\solvers\solver.py:108: RuntimeWarning: overflow encountered in multiply
#   self.RHSvector += (1 - underRelaxation) * self.matrix.takeDiagonal() * numerix.array(self.var).flatten()
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\solvers\solver.py:116: RuntimeWarning: invalid value encountered in subtract
#   return Lx - self.RHSvector
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-d771bec8eb8f> in <module>
#      47 for sweep in range(sweeps):
#      48     xVelocityEq.cacheMatrix()
# ---> 49     xres = xVelocityEq.sweep(var = xVelocity, underRelaxation = velocityRelaxation)
#      50
#      51     xmat = xVelocityEq.matrix
#
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\terms\term.py in sweep(self, var, solver, boundaryConditions, dt, underRelaxation, residualFn, cacheResidual, cacheError)
#     230             self.residualVector = None
#     231
# --> 232         solver._solve()
#     233
#     234         return residual
#
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\solvers\scipy\scipySolver.py in _solve(self)
#      24              raise Exception("SciPy solvers cannot be used with multiple processors")
#      25
# ---> 26          self.var[:] = numerix.reshape(self._solve_(self.matrix, self.var.ravel(), numerix.array(self.RHSvector)), self.var.shape)
#
# C:\ProgramData\Anaconda3\lib\site-packages\fipy\solvers\scipy\linearLUSolver.py in _solve_(self, L, x, b)
#      32                                             relax=1,
#      33                                             panel_size=10,
# ---> 34                                             permc_spec=3)
#      35
#      36         error0 = numerix.sqrt(numerix.sum((L * x - b)**2))
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\sparse\linalg\dsolve\linsolve.py in splu(A, permc_spec, diag_pivot_thresh, relax, panel_size, options)
#     309         _options.update(options)
#     310     return _superlu.gstrf(N, A.nnz, A.data, A.indices, A.indptr,
# --> 311                           ilu=False, options=_options)
#     312
#     313
#
# RuntimeError: Factor is exactly singular
